# %% [markdown]
# # Create Modelling Data for GAM
# ## Setup Jupyter Notebook

# %% [markdown]
# ### Import packages

# %%
# Import external packages
import pandas as pd
import os
import numpy as np
import random
import pyarrow.parquet as pq
import shutil

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import sys

# %%
# Import the internal package
package_loc = r"../"

# Add the package location to system paths
sys.path.append(package_loc)

from src import utils

# %% [markdown]
# ### Define Paths

# %%
# Define the directories for input and output
dir_input = f"input"
dir_export = f"export"

print(os.listdir(dir_input))
print(os.listdir(dir_export))
# Out:
# ['.gitkeep', 'CMI TA DB 2016 Datasheet v02 2024-06-17.xlsb', 'CMI TA DB 2017 Datasheet v02 2024-06-17.xlsb', 'CMI TA DB 2018 Datasheet v01 2022-05-20.xlsb', 'CMI TA DB 2019 Datasheet v01 2022-05-20.xlsb', 'CMI TA DB 2020 Datasheet v01 2022-05-20.xlsb']
# ['CMI Categorical Bands (with CalendarYear).xlsx', 'gam_modelling_data_v2.parquet']

# %% [markdown]
# ### Set Variables

# %%
title_fontsize = 25 
label_fontsize = 20 
ticker_fontsize = 15

data_version = "v2"

# %% [markdown]
# ## Import Raw Data

# %%
###########################################################################
###########################################################################

data_dict = {
    "CY2016": "CMI TA DB 2016 Datasheet v02 2024-06-17.xlsb",
    "CY2017": "CMI TA DB 2017 Datasheet v02 2024-06-17.xlsb",
    "CY2018": "CMI TA DB 2018 Datasheet v01 2022-05-20.xlsb",
    "CY2019": "CMI TA DB 2019 Datasheet v01 2022-05-20.xlsb",
    "CY2020": "CMI TA DB 2020 Datasheet v01 2022-05-20.xlsb",
}

unique_id = "unique_id"
holdout = "holdout"
fold = "random_fold"

###########################################################################
###########################################################################

df_data = utils.compile_data(
    data_dict, dir_input, unique_id=unique_id, holdout=holdout, fold=fold
)
df_data

# %%
# Check if there is any null value
df_data.isnull().sum()
# Out:
# ProductCategory         0
# Gender                  0
# SmokerStatus            0
# DistributionChannel     0
# CommencementYear        0
# JointLifeStatus         0
# SumAssuredBand          0
# Age                     0
# Duration                0
# LivesExposure           0
# AmountsExposure         0
# IncurredClaims          0
# AmountIncurred          0
# ExpectedClaims          0
# ExpectedAmountClaims    0
# ComparatorTable         0
# CalendarYear            0
# unique_id               0
# holdout                 0
# random_fold             0
# dtype: int64

# %%
# Check column types
df_data.dtypes
# Out:
# ProductCategory             str
# Gender                      str
# SmokerStatus                str
# DistributionChannel         str
# CommencementYear            str
# JointLifeStatus             str
# SumAssuredBand              str
# Age                       int64
# Duration                    str
# LivesExposure           float64
# AmountsExposure         float64
# IncurredClaims          float64
# AmountIncurred          float64
# ExpectedClaims          float64
# ExpectedAmountClaims    float64
# ComparatorTable             str
# CalendarYear                str
# unique_id                 int64
# holdout                   int64
# random_fold               int32
# dtype: object

# %% [markdown]
# ## Sense Check Column Distributions

# %%
def make_pretty_pivot(styler, format_dict, caption, bar_dict):

    headers = {
        "selector": "th:not(.index_name)",
        "props": "background-color: #000066; color: white;",
    }

    styler.set_caption(caption)
    styler.format(format_dict)

    for col, color in bar_dict.items():
        styler.bar(color=color, subset=col, props="width: 5em;") 

    styler.set_table_styles(
        [
            {
                "selector": "caption",
                "props": [
                    ("font-weight", "bold"),
                    ("font-size", "100%"),
                    ("background-color", "#000066"),
                    ("color", "white"),
                ],
            },
            {"selector": "th", "props": "border: 1px solid white"},
            {
                "selector": "td",
                "props": "border: 1px solid #000066; text-align: center",
            },
            {"selector": "tr", "props": "border: 1px solid #000066"},
            {"selector": ".index_name", "props": "border: 1px solid #000066"},
            headers,
        ]
    )

    return styler

# %%
###################################################################
###################################################################

var1 = holdout
var2 = fold
target = "IncurredClaims"
weight = "LivesExposure"

mix = "mix"
freq = "actual"
bar_dict = {mix: "steelblue", freq: "darkcyan"}
caption = "Claim Frequency"

###################################################################
###################################################################

# Check that actual frequencies by random folds are similar
df_data_gb = df_data.groupby([var1, var2])[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]


format_dict = {
    freq: "{:,.4%}",
    mix: "{:,.2%}",
    target: "{:,.0f}",
    weight: "{:,.0f}",
}
df_data_gb.style.pipe(lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict))
# Out:
# <style type="text/css">
# #T_d3f32 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_d3f32 th {
#   border: 1px solid white;
# }
# #T_d3f32 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_d3f32 tr {
#   border: 1px solid #000066;
# }
# #T_d3f32 .index_name {
#   border: 1px solid #000066;
# }
# #T_d3f32 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_d3f32_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 80.2%, transparent 80.2%);
# }
# #T_d3f32_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 99.9%, transparent 99.9%);
# }
# #T_d3f32_row1_col2, #T_d3f32_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 80.1%, transparent 80.1%);
# }
# #T_d3f32_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# #T_d3f32_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 80.4%, transparent 80.4%);
# }
# #T_d3f32_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 96.4%, transparent 96.4%);
# }
# #T_d3f32_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 79.6%, transparent 79.6%);
# }
# #T_d3f32_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 97.7%, transparent 97.7%);
# }
# #T_d3f32_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 99.5%, transparent 99.5%);
# }
# #T_d3f32_row5_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_d3f32_row5_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 98.7%, transparent 98.7%);
# }
# </style>
# <table id="T_d3f32">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3f32_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_d3f32_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_d3f32_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_d3f32_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >holdout</th>
#       <th class="index_name level1" >random_fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3f32_level0_row0" class="row_heading level0 row0" rowspan="5">0</th>
#       <th id="T_d3f32_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_d3f32_row0_col0" class="data row0 col0" >5,807,452</td>
#       <td id="T_d3f32_row0_col1" class="data row0 col1" >7,724</td>
#       <td id="T_d3f32_row0_col2" class="data row0 col2" >16.02%</td>
#       <td id="T_d3f32_row0_col3" class="data row0 col3" >0.1330%</td>
#     </tr>
#     <tr>
#       <th id="T_d3f32_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_d3f32_row1_col0" class="data row1 col0" >5,804,380</td>
#       <td id="T_d3f32_row1_col1" class="data row1 col1" >7,728</td>
#       <td id="T_d3f32_row1_col2" class="data row1 col2" >16.01%</td>
#       <td id="T_d3f32_row1_col3" class="data row1 col3" >0.1331%</td>
#     </tr>
#     <tr>
#       <th id="T_d3f32_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_d3f32_row2_col0" class="data row2 col0" >5,822,582</td>
#       <td id="T_d3f32_row2_col1" class="data row2 col1" >7,469</td>
#       <td id="T_d3f32_row2_col2" class="data row2 col2" >16.06%</td>
#       <td id="T_d3f32_row2_col3" class="data row2 col3" >0.1283%</td>
#     </tr>
#     <tr>
#       <th id="T_d3f32_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_d3f32_row3_col0" class="data row3 col0" >5,767,609</td>
#       <td id="T_d3f32_row3_col1" class="data row3 col1" >7,500</td>
#       <td id="T_d3f32_row3_col2" class="data row3 col2" >15.91%</td>
#       <td id="T_d3f32_row3_col3" class="data row3 col3" >0.1300%</td>
#     </tr>
#     <tr>
#       <th id="T_d3f32_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_d3f32_row4_col0" class="data row4 col0" >5,799,619</td>
#       <td id="T_d3f32_row4_col1" class="data row4 col1" >7,684</td>
#       <td id="T_d3f32_row4_col2" class="data row4 col2" >16.00%</td>
#       <td id="T_d3f32_row4_col3" class="data row4 col3" >0.1325%</td>
#     </tr>
#     <tr>
#       <th id="T_d3f32_level0_row5" class="row_heading level0 row5" >1</th>
#       <th id="T_d3f32_level1_row5" class="row_heading level1 row5" >6</th>
#       <td id="T_d3f32_row5_col0" class="data row5 col0" >7,243,858</td>
#       <td id="T_d3f32_row5_col1" class="data row5 col1" >9,516</td>
#       <td id="T_d3f32_row5_col2" class="data row5 col2" >19.99%</td>
#       <td id="T_d3f32_row5_col3" class="data row5 col3" >0.1314%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Transform Duration into an ordinal variable
var = "Duration"
category_order = [*[str(x) for x in range(10)], "10+"]
df_data[var] = pd.Categorical(df_data[var], categories=category_order, ordered=True)

df_data_gb = df_data.groupby(var)[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]

df_data_gb.style.pipe(lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict))
# Out:
# <style type="text/css">
# #T_e4ba6 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_e4ba6 th {
#   border: 1px solid white;
# }
# #T_e4ba6 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_e4ba6 tr {
#   border: 1px solid #000066;
# }
# #T_e4ba6 .index_name {
#   border: 1px solid #000066;
# }
# #T_e4ba6 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_e4ba6_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 42.0%, transparent 42.0%);
# }
# #T_e4ba6_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 20.4%, transparent 20.4%);
# }
# #T_e4ba6_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 37.4%, transparent 37.4%);
# }
# #T_e4ba6_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 34.5%, transparent 34.5%);
# }
# #T_e4ba6_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 32.8%, transparent 32.8%);
# }
# #T_e4ba6_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 45.3%, transparent 45.3%);
# }
# #T_e4ba6_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 29.4%, transparent 29.4%);
# }
# #T_e4ba6_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 57.1%, transparent 57.1%);
# }
# #T_e4ba6_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 26.9%, transparent 26.9%);
# }
# #T_e4ba6_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 63.1%, transparent 63.1%);
# }
# #T_e4ba6_row5_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 24.0%, transparent 24.0%);
# }
# #T_e4ba6_row5_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 69.4%, transparent 69.4%);
# }
# #T_e4ba6_row6_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 22.3%, transparent 22.3%);
# }
# #T_e4ba6_row6_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 74.6%, transparent 74.6%);
# }
# #T_e4ba6_row7_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 20.3%, transparent 20.3%);
# }
# #T_e4ba6_row7_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 81.1%, transparent 81.1%);
# }
# #T_e4ba6_row8_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 18.3%, transparent 18.3%);
# }
# #T_e4ba6_row8_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 85.0%, transparent 85.0%);
# }
# #T_e4ba6_row9_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 16.6%, transparent 16.6%);
# }
# #T_e4ba6_row9_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 81.8%, transparent 81.8%);
# }
# #T_e4ba6_row10_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_e4ba6_row10_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_e4ba6">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4ba6_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_e4ba6_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_e4ba6_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_e4ba6_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Duration</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4ba6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4ba6_row0_col0" class="data row0 col0" >4,113,773</td>
#       <td id="T_e4ba6_row0_col1" class="data row0 col1" >1,642</td>
#       <td id="T_e4ba6_row0_col2" class="data row0 col2" >11.35%</td>
#       <td id="T_e4ba6_row0_col3" class="data row0 col3" >0.0399%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4ba6_row1_col0" class="data row1 col0" >3,663,973</td>
#       <td id="T_e4ba6_row1_col1" class="data row1 col1" >2,467</td>
#       <td id="T_e4ba6_row1_col2" class="data row1 col2" >10.11%</td>
#       <td id="T_e4ba6_row1_col3" class="data row1 col3" >0.0673%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4ba6_row2_col0" class="data row2 col0" >3,213,466</td>
#       <td id="T_e4ba6_row2_col1" class="data row2 col1" >2,842</td>
#       <td id="T_e4ba6_row2_col2" class="data row2 col2" >8.87%</td>
#       <td id="T_e4ba6_row2_col3" class="data row2 col3" >0.0884%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4ba6_row3_col0" class="data row3 col0" >2,884,806</td>
#       <td id="T_e4ba6_row3_col1" class="data row3 col1" >3,217</td>
#       <td id="T_e4ba6_row3_col2" class="data row3 col2" >7.96%</td>
#       <td id="T_e4ba6_row3_col3" class="data row3 col3" >0.1115%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4ba6_row4_col0" class="data row4 col0" >2,630,577</td>
#       <td id="T_e4ba6_row4_col1" class="data row4 col1" >3,241</td>
#       <td id="T_e4ba6_row4_col2" class="data row4 col2" >7.26%</td>
#       <td id="T_e4ba6_row4_col3" class="data row4 col3" >0.1232%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4ba6_row5_col0" class="data row5 col0" >2,355,861</td>
#       <td id="T_e4ba6_row5_col1" class="data row5 col1" >3,191</td>
#       <td id="T_e4ba6_row5_col2" class="data row5 col2" >6.50%</td>
#       <td id="T_e4ba6_row5_col3" class="data row5 col3" >0.1354%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4ba6_row6_col0" class="data row6 col0" >2,182,373</td>
#       <td id="T_e4ba6_row6_col1" class="data row6 col1" >3,179</td>
#       <td id="T_e4ba6_row6_col2" class="data row6 col2" >6.02%</td>
#       <td id="T_e4ba6_row6_col3" class="data row6 col3" >0.1457%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4ba6_row7_col0" class="data row7 col0" >1,984,901</td>
#       <td id="T_e4ba6_row7_col1" class="data row7 col1" >3,143</td>
#       <td id="T_e4ba6_row7_col2" class="data row7 col2" >5.48%</td>
#       <td id="T_e4ba6_row7_col3" class="data row7 col3" >0.1583%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4ba6_row8_col0" class="data row8 col0" >1,797,171</td>
#       <td id="T_e4ba6_row8_col1" class="data row8 col1" >2,982</td>
#       <td id="T_e4ba6_row8_col2" class="data row8 col2" >4.96%</td>
#       <td id="T_e4ba6_row8_col3" class="data row8 col3" >0.1659%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4ba6_row9_col0" class="data row9 col0" >1,621,867</td>
#       <td id="T_e4ba6_row9_col1" class="data row9 col1" >2,590</td>
#       <td id="T_e4ba6_row9_col2" class="data row9 col2" >4.47%</td>
#       <td id="T_e4ba6_row9_col3" class="data row9 col3" >0.1597%</td>
#     </tr>
#     <tr>
#       <th id="T_e4ba6_level0_row10" class="row_heading level0 row10" >10+</th>
#       <td id="T_e4ba6_row10_col0" class="data row10 col0" >9,796,733</td>
#       <td id="T_e4ba6_row10_col1" class="data row10 col1" >19,127</td>
#       <td id="T_e4ba6_row10_col2" class="data row10 col2" >27.03%</td>
#       <td id="T_e4ba6_row10_col3" class="data row10 col3" >0.1952%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Transform SumAssuredBand into an ordinal variable
category_order = [
    "£0-£25000",
    "£25001-£75000",
    "£75001-£125000",
    "£125001-£250000",
    "£250001+",
]

var = "SumAssuredBand"

df_data[var] = pd.Categorical(df_data[var], categories=category_order, ordered=True)

df_data_gb = df_data.groupby(var)[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]
df_data_gb.style.pipe(lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict))
# Out:
# <style type="text/css">
# #T_c98c7 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_c98c7 th {
#   border: 1px solid white;
# }
# #T_c98c7 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_c98c7 tr {
#   border: 1px solid #000066;
# }
# #T_c98c7 .index_name {
#   border: 1px solid #000066;
# }
# #T_c98c7 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_c98c7_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 20.5%, transparent 20.5%);
# }
# #T_c98c7_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# #T_c98c7_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 56.6%, transparent 56.6%);
# }
# #T_c98c7_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 48.8%, transparent 48.8%);
# }
# #T_c98c7_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 75.5%, transparent 75.5%);
# }
# #T_c98c7_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 29.6%, transparent 29.6%);
# }
# #T_c98c7_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_c98c7_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 19.6%, transparent 19.6%);
# }
# #T_c98c7_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 43.5%, transparent 43.5%);
# }
# #T_c98c7_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 15.7%, transparent 15.7%);
# }
# </style>
# <table id="T_c98c7">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c98c7_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_c98c7_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_c98c7_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_c98c7_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SumAssuredBand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c98c7_level0_row0" class="row_heading level0 row0" >£0-£25000</th>
#       <td id="T_c98c7_row0_col0" class="data row0 col0" >2,513,809</td>
#       <td id="T_c98c7_row0_col1" class="data row0 col1" >10,088</td>
#       <td id="T_c98c7_row0_col2" class="data row0 col2" >6.94%</td>
#       <td id="T_c98c7_row0_col3" class="data row0 col3" >0.4013%</td>
#     </tr>
#     <tr>
#       <th id="T_c98c7_level0_row1" class="row_heading level0 row1" >£25001-£75000</th>
#       <td id="T_c98c7_row1_col0" class="data row1 col0" >6,930,909</td>
#       <td id="T_c98c7_row1_col1" class="data row1 col1" >13,565</td>
#       <td id="T_c98c7_row1_col2" class="data row1 col2" >19.12%</td>
#       <td id="T_c98c7_row1_col3" class="data row1 col3" >0.1957%</td>
#     </tr>
#     <tr>
#       <th id="T_c98c7_level0_row2" class="row_heading level0 row2" >£75001-£125000</th>
#       <td id="T_c98c7_row2_col0" class="data row2 col0" >9,242,826</td>
#       <td id="T_c98c7_row2_col1" class="data row2 col1" >10,975</td>
#       <td id="T_c98c7_row2_col2" class="data row2 col2" >25.50%</td>
#       <td id="T_c98c7_row2_col3" class="data row2 col3" >0.1187%</td>
#     </tr>
#     <tr>
#       <th id="T_c98c7_level0_row3" class="row_heading level0 row3" >£125001-£250000</th>
#       <td id="T_c98c7_row3_col0" class="data row3 col0" >12,238,301</td>
#       <td id="T_c98c7_row3_col1" class="data row3 col1" >9,637</td>
#       <td id="T_c98c7_row3_col2" class="data row3 col2" >33.77%</td>
#       <td id="T_c98c7_row3_col3" class="data row3 col3" >0.0787%</td>
#     </tr>
#     <tr>
#       <th id="T_c98c7_level0_row4" class="row_heading level0 row4" >£250001+</th>
#       <td id="T_c98c7_row4_col0" class="data row4 col0" >5,319,656</td>
#       <td id="T_c98c7_row4_col1" class="data row4 col1" >3,356</td>
#       <td id="T_c98c7_row4_col2" class="data row4 col2" >14.68%</td>
#       <td id="T_c98c7_row4_col3" class="data row4 col3" >0.0631%</td>
#     </tr>
#   </tbody>
# </table>

# %%
###################################################################
###################################################################

var = "CommencementYear"

###################################################################
###################################################################

df_data_gb = df_data.groupby(var)[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]
df_data_gb.style.pipe(
    lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict)
)
# Out:
# <style type="text/css">
# #T_fed68 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_fed68 th {
#   border: 1px solid white;
# }
# #T_fed68 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_fed68 tr {
#   border: 1px solid #000066;
# }
# #T_fed68 .index_name {
#   border: 1px solid #000066;
# }
# #T_fed68 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_fed68_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 21.9%, transparent 21.9%);
# }
# #T_fed68_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# #T_fed68_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 11.1%, transparent 11.1%);
# }
# #T_fed68_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 88.0%, transparent 88.0%);
# }
# #T_fed68_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 24.1%, transparent 24.1%);
# }
# #T_fed68_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 91.1%, transparent 91.1%);
# }
# #T_fed68_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 33.0%, transparent 33.0%);
# }
# #T_fed68_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 89.4%, transparent 89.4%);
# }
# #T_fed68_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 42.9%, transparent 42.9%);
# }
# #T_fed68_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 89.5%, transparent 89.5%);
# }
# #T_fed68_row5_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 46.2%, transparent 46.2%);
# }
# #T_fed68_row5_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 86.1%, transparent 86.1%);
# }
# #T_fed68_row6_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 40.8%, transparent 40.8%);
# }
# #T_fed68_row6_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 82.0%, transparent 82.0%);
# }
# #T_fed68_row7_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 42.7%, transparent 42.7%);
# }
# #T_fed68_row7_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 71.0%, transparent 71.0%);
# }
# #T_fed68_row8_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 47.8%, transparent 47.8%);
# }
# #T_fed68_row8_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 70.6%, transparent 70.6%);
# }
# #T_fed68_row9_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 48.2%, transparent 48.2%);
# }
# #T_fed68_row9_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 67.9%, transparent 67.9%);
# }
# #T_fed68_row10_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 56.6%, transparent 56.6%);
# }
# #T_fed68_row10_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 71.1%, transparent 71.1%);
# }
# #T_fed68_row11_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 64.1%, transparent 64.1%);
# }
# #T_fed68_row11_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 66.6%, transparent 66.6%);
# }
# #T_fed68_row12_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 72.6%, transparent 72.6%);
# }
# #T_fed68_row12_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 66.8%, transparent 66.8%);
# }
# #T_fed68_row13_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 85.9%, transparent 85.9%);
# }
# #T_fed68_row13_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 58.9%, transparent 58.9%);
# }
# #T_fed68_row14_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 82.2%, transparent 82.2%);
# }
# #T_fed68_row14_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 58.0%, transparent 58.0%);
# }
# #T_fed68_row15_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 92.4%, transparent 92.4%);
# }
# #T_fed68_row15_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 47.4%, transparent 47.4%);
# }
# #T_fed68_row16_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_fed68_row16_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 36.4%, transparent 36.4%);
# }
# #T_fed68_row17_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 99.5%, transparent 99.5%);
# }
# #T_fed68_row17_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 33.6%, transparent 33.6%);
# }
# #T_fed68_row18_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 87.6%, transparent 87.6%);
# }
# #T_fed68_row18_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 30.2%, transparent 30.2%);
# }
# #T_fed68_row19_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 67.3%, transparent 67.3%);
# }
# #T_fed68_row19_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 25.9%, transparent 25.9%);
# }
# #T_fed68_row20_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 41.6%, transparent 41.6%);
# }
# #T_fed68_row20_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 20.1%, transparent 20.1%);
# }
# #T_fed68_row21_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 14.7%, transparent 14.7%);
# }
# #T_fed68_row21_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 17.8%, transparent 17.8%);
# }
# </style>
# <table id="T_fed68">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fed68_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_fed68_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_fed68_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_fed68_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CommencementYear</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fed68_level0_row0" class="row_heading level0 row0" >1999 or earlier</th>
#       <td id="T_fed68_row0_col0" class="data row0 col0" >650,398</td>
#       <td id="T_fed68_row0_col1" class="data row0 col1" >1,515</td>
#       <td id="T_fed68_row0_col2" class="data row0 col2" >1.79%</td>
#       <td id="T_fed68_row0_col3" class="data row0 col3" >0.2330%</td>
#     </tr>
#     <tr>
#       <th id="T_fed68_level0_row1" class="row_heading level0 row1" >2000</th>
#       <td id="T_fed68_row1_col0" class="data row1 col0" >330,233</td>
#       <td id="T_fed68_row1_col1" class="data row1 col1" >677</td>
#       <td id="T_fed68_row1_col2" class="data row1 col2" >0.91%</td>
#       <td id="T_fed68_row1_col3" class="data row1 col3" >0.2050%</td>
#     </tr>
#     <tr>
#       <th id="T_fed68_level0_row2" class="row_heading level0 row2" >2001</th>
#       <td id="T_fed68_row2_col0" class="data row2 col0" >713,202</td>
#       <td id="T_fed68_row2_col1" class="data row2 col1" >1,514</td>
#       <td id="T_fed68_row2_col2" class="data row2 col2" >1.97%</td>
#       <td id="T_fed68_row2_col3" class="data row2 col3" >0.2123%</td>
#     </tr>
#     <tr>
#       <th id="T_fed68_level0_row3" class="row_heading level0 row3" >2002</th>
#       <td id="T_fed68_row3_col0" class="data row3 col0" >976,529</td>
#       <td id="T_fed68_row3_col1" class="data row3 col1" >2,033</td>
#       <td id="T_fed68_row3_col2" class="data row3 col2" >2.69%</td>
#       <td id="T_fed68_row3_col3" class="data row3 col3" >0.2082%</td>
#     </tr>
#     <tr>
#       <th id="T_fed68_level0_row4" class="row_heading level0 row4" >2003</th>
#       <td id="T_fed68_row4_col0" class="data row4 col0" >1,272,213</td>
#       <td id="T_fed68_row4_col1" class="data row4 col1" >2,651</td>
#       <td id="T_fed68_row4_col2" class="data row4 col2" >3.51%</td>
#       <td id="T_fed68_row4_col3" class="data row4 col3" >0.2084%</td>
#     </tr>
#     <tr>
#       <th id="T_fed68_level0_row5" class="row_heading level0 row5" >2

# %% [markdown]
# ## Feature Engineering
# ### Numerical Features

# %%
# Transform Duration into a numerical variable
df_data["Duration"] = df_data["Duration"].str.replace(r"\D", "", regex=True)
df_data["Duration"] = df_data["Duration"].astype(int)

v = "Duration"

df_data_gb = df_data.groupby(v)[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]

df_data_gb.style.pipe(lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict))
# Out:
# <style type="text/css">
# #T_0cf05 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_0cf05 th {
#   border: 1px solid white;
# }
# #T_0cf05 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_0cf05 tr {
#   border: 1px solid #000066;
# }
# #T_0cf05 .index_name {
#   border: 1px solid #000066;
# }
# #T_0cf05 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_0cf05_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 42.0%, transparent 42.0%);
# }
# #T_0cf05_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 20.4%, transparent 20.4%);
# }
# #T_0cf05_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 37.4%, transparent 37.4%);
# }
# #T_0cf05_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 34.5%, transparent 34.5%);
# }
# #T_0cf05_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 32.8%, transparent 32.8%);
# }
# #T_0cf05_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 45.3%, transparent 45.3%);
# }
# #T_0cf05_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 29.4%, transparent 29.4%);
# }
# #T_0cf05_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 57.1%, transparent 57.1%);
# }
# #T_0cf05_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 26.9%, transparent 26.9%);
# }
# #T_0cf05_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 63.1%, transparent 63.1%);
# }
# #T_0cf05_row5_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 24.0%, transparent 24.0%);
# }
# #T_0cf05_row5_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 69.4%, transparent 69.4%);
# }
# #T_0cf05_row6_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 22.3%, transparent 22.3%);
# }
# #T_0cf05_row6_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 74.6%, transparent 74.6%);
# }
# #T_0cf05_row7_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 20.3%, transparent 20.3%);
# }
# #T_0cf05_row7_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 81.1%, transparent 81.1%);
# }
# #T_0cf05_row8_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 18.3%, transparent 18.3%);
# }
# #T_0cf05_row8_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 85.0%, transparent 85.0%);
# }
# #T_0cf05_row9_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 16.6%, transparent 16.6%);
# }
# #T_0cf05_row9_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 81.8%, transparent 81.8%);
# }
# #T_0cf05_row10_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_0cf05_row10_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_0cf05">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cf05_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_0cf05_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_0cf05_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_0cf05_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Duration</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cf05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cf05_row0_col0" class="data row0 col0" >4,113,773</td>
#       <td id="T_0cf05_row0_col1" class="data row0 col1" >1,642</td>
#       <td id="T_0cf05_row0_col2" class="data row0 col2" >11.35%</td>
#       <td id="T_0cf05_row0_col3" class="data row0 col3" >0.0399%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cf05_row1_col0" class="data row1 col0" >3,663,973</td>
#       <td id="T_0cf05_row1_col1" class="data row1 col1" >2,467</td>
#       <td id="T_0cf05_row1_col2" class="data row1 col2" >10.11%</td>
#       <td id="T_0cf05_row1_col3" class="data row1 col3" >0.0673%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cf05_row2_col0" class="data row2 col0" >3,213,466</td>
#       <td id="T_0cf05_row2_col1" class="data row2 col1" >2,842</td>
#       <td id="T_0cf05_row2_col2" class="data row2 col2" >8.87%</td>
#       <td id="T_0cf05_row2_col3" class="data row2 col3" >0.0884%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cf05_row3_col0" class="data row3 col0" >2,884,806</td>
#       <td id="T_0cf05_row3_col1" class="data row3 col1" >3,217</td>
#       <td id="T_0cf05_row3_col2" class="data row3 col2" >7.96%</td>
#       <td id="T_0cf05_row3_col3" class="data row3 col3" >0.1115%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cf05_row4_col0" class="data row4 col0" >2,630,577</td>
#       <td id="T_0cf05_row4_col1" class="data row4 col1" >3,241</td>
#       <td id="T_0cf05_row4_col2" class="data row4 col2" >7.26%</td>
#       <td id="T_0cf05_row4_col3" class="data row4 col3" >0.1232%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0cf05_row5_col0" class="data row5 col0" >2,355,861</td>
#       <td id="T_0cf05_row5_col1" class="data row5 col1" >3,191</td>
#       <td id="T_0cf05_row5_col2" class="data row5 col2" >6.50%</td>
#       <td id="T_0cf05_row5_col3" class="data row5 col3" >0.1354%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0cf05_row6_col0" class="data row6 col0" >2,182,373</td>
#       <td id="T_0cf05_row6_col1" class="data row6 col1" >3,179</td>
#       <td id="T_0cf05_row6_col2" class="data row6 col2" >6.02%</td>
#       <td id="T_0cf05_row6_col3" class="data row6 col3" >0.1457%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0cf05_row7_col0" class="data row7 col0" >1,984,901</td>
#       <td id="T_0cf05_row7_col1" class="data row7 col1" >3,143</td>
#       <td id="T_0cf05_row7_col2" class="data row7 col2" >5.48%</td>
#       <td id="T_0cf05_row7_col3" class="data row7 col3" >0.1583%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0cf05_row8_col0" class="data row8 col0" >1,797,171</td>
#       <td id="T_0cf05_row8_col1" class="data row8 col1" >2,982</td>
#       <td id="T_0cf05_row8_col2" class="data row8 col2" >4.96%</td>
#       <td id="T_0cf05_row8_col3" class="data row8 col3" >0.1659%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0cf05_row9_col0" class="data row9 col0" >1,621,867</td>
#       <td id="T_0cf05_row9_col1" class="data row9 col1" >2,590</td>
#       <td id="T_0cf05_row9_col2" class="data row9 col2" >4.47%</td>
#       <td id="T_0cf05_row9_col3" class="data row9 col3" >0.1597%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf05_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0cf05_row10_col0" class="data row10 col0" >9,796,733</td>
#       <td id="T_0cf05_row10_col1" class="data row10 col1" >19,127</td>
#       <td id="T_0cf05_row10_col2" class="data row10 col2" >27.03%</td>
#       <td id="T_0cf05_row10_col3" class="data row10 col3" >0.1952%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Transform CommencementYear into a numerical variable 
df_data["CommencementYear"] = df_data["CommencementYear"].str.replace(r"\D", "", regex=True)
df_data["CommencementYear"] = df_data["CommencementYear"].astype(int)

v = "CommencementYear"

df_data_gb = df_data.groupby(v)[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]

df_data_gb.style.pipe(
    lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict)
)
# Out:
# <style type="text/css">
# #T_83019 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_83019 th {
#   border: 1px solid white;
# }
# #T_83019 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_83019 tr {
#   border: 1px solid #000066;
# }
# #T_83019 .index_name {
#   border: 1px solid #000066;
# }
# #T_83019 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_83019_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 21.9%, transparent 21.9%);
# }
# #T_83019_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# #T_83019_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 11.1%, transparent 11.1%);
# }
# #T_83019_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 88.0%, transparent 88.0%);
# }
# #T_83019_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 24.1%, transparent 24.1%);
# }
# #T_83019_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 91.1%, transparent 91.1%);
# }
# #T_83019_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 33.0%, transparent 33.0%);
# }
# #T_83019_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 89.4%, transparent 89.4%);
# }
# #T_83019_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 42.9%, transparent 42.9%);
# }
# #T_83019_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 89.5%, transparent 89.5%);
# }
# #T_83019_row5_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 46.2%, transparent 46.2%);
# }
# #T_83019_row5_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 86.1%, transparent 86.1%);
# }
# #T_83019_row6_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 40.8%, transparent 40.8%);
# }
# #T_83019_row6_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 82.0%, transparent 82.0%);
# }
# #T_83019_row7_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 42.7%, transparent 42.7%);
# }
# #T_83019_row7_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 71.0%, transparent 71.0%);
# }
# #T_83019_row8_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 47.8%, transparent 47.8%);
# }
# #T_83019_row8_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 70.6%, transparent 70.6%);
# }
# #T_83019_row9_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 48.2%, transparent 48.2%);
# }
# #T_83019_row9_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 67.9%, transparent 67.9%);
# }
# #T_83019_row10_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 56.6%, transparent 56.6%);
# }
# #T_83019_row10_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 71.1%, transparent 71.1%);
# }
# #T_83019_row11_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 64.1%, transparent 64.1%);
# }
# #T_83019_row11_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 66.6%, transparent 66.6%);
# }
# #T_83019_row12_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 72.6%, transparent 72.6%);
# }
# #T_83019_row12_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 66.8%, transparent 66.8%);
# }
# #T_83019_row13_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 85.9%, transparent 85.9%);
# }
# #T_83019_row13_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 58.9%, transparent 58.9%);
# }
# #T_83019_row14_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 82.2%, transparent 82.2%);
# }
# #T_83019_row14_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 58.0%, transparent 58.0%);
# }
# #T_83019_row15_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 92.4%, transparent 92.4%);
# }
# #T_83019_row15_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 47.4%, transparent 47.4%);
# }
# #T_83019_row16_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_83019_row16_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 36.4%, transparent 36.4%);
# }
# #T_83019_row17_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 99.5%, transparent 99.5%);
# }
# #T_83019_row17_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 33.6%, transparent 33.6%);
# }
# #T_83019_row18_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 87.6%, transparent 87.6%);
# }
# #T_83019_row18_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 30.2%, transparent 30.2%);
# }
# #T_83019_row19_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 67.3%, transparent 67.3%);
# }
# #T_83019_row19_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 25.9%, transparent 25.9%);
# }
# #T_83019_row20_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 41.6%, transparent 41.6%);
# }
# #T_83019_row20_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 20.1%, transparent 20.1%);
# }
# #T_83019_row21_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 14.7%, transparent 14.7%);
# }
# #T_83019_row21_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 17.8%, transparent 17.8%);
# }
# </style>
# <table id="T_83019">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83019_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_83019_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_83019_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_83019_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CommencementYear</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83019_level0_row0" class="row_heading level0 row0" >1999</th>
#       <td id="T_83019_row0_col0" class="data row0 col0" >650,398</td>
#       <td id="T_83019_row0_col1" class="data row0 col1" >1,515</td>
#       <td id="T_83019_row0_col2" class="data row0 col2" >1.79%</td>
#       <td id="T_83019_row0_col3" class="data row0 col3" >0.2330%</td>
#     </tr>
#     <tr>
#       <th id="T_83019_level0_row1" class="row_heading level0 row1" >2000</th>
#       <td id="T_83019_row1_col0" class="data row1 col0" >330,233</td>
#       <td id="T_83019_row1_col1" class="data row1 col1" >677</td>
#       <td id="T_83019_row1_col2" class="data row1 col2" >0.91%</td>
#       <td id="T_83019_row1_col3" class="data row1 col3" >0.2050%</td>
#     </tr>
#     <tr>
#       <th id="T_83019_level0_row2" class="row_heading level0 row2" >2001</th>
#       <td id="T_83019_row2_col0" class="data row2 col0" >713,202</td>
#       <td id="T_83019_row2_col1" class="data row2 col1" >1,514</td>
#       <td id="T_83019_row2_col2" class="data row2 col2" >1.97%</td>
#       <td id="T_83019_row2_col3" class="data row2 col3" >0.2123%</td>
#     </tr>
#     <tr>
#       <th id="T_83019_level0_row3" class="row_heading level0 row3" >2002</th>
#       <td id="T_83019_row3_col0" class="data row3 col0" >976,529</td>
#       <td id="T_83019_row3_col1" class="data row3 col1" >2,033</td>
#       <td id="T_83019_row3_col2" class="data row3 col2" >2.69%</td>
#       <td id="T_83019_row3_col3" class="data row3 col3" >0.2082%</td>
#     </tr>
#     <tr>
#       <th id="T_83019_level0_row4" class="row_heading level0 row4" >2003</th>
#       <td id="T_83019_row4_col0" class="data row4 col0" >1,272,213</td>
#       <td id="T_83019_row4_col1" class="data row4 col1" >2,651</td>
#       <td id="T_83019_row4_col2" class="data row4 col2" >3.51%</td>
#       <td id="T_83019_row4_col3" class="data row4 col3" >0.2084%</td>
#     </tr>
#     <tr>
#       <th id="T_83019_level0_row5" class="row_heading level0 row5" >2004</th>

# %%
# Transform SumAssuredBand into a numerical variable 

v = "SumAssuredBand"
sab_map = {"£0-£25000": 1, "£25001-£75000": 2, "£75001-£125000": 3, "£125001-£250000": 4, "£250001+": 5}
df_data["SumAssuredBand"] = df_data["SumAssuredBand"].map(sab_map)

# df_data[v] = pd.Categorical(df_data[v], categories=category_order, ordered=True)

df_data_gb = df_data.groupby(v)[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]

df_data_gb.style.pipe(
    lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict)
)
# Out:
# <style type="text/css">
# #T_19a53 caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_19a53 th {
#   border: 1px solid white;
# }
# #T_19a53 td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_19a53 tr {
#   border: 1px solid #000066;
# }
# #T_19a53 .index_name {
#   border: 1px solid #000066;
# }
# #T_19a53 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_19a53_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 20.5%, transparent 20.5%);
# }
# #T_19a53_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# #T_19a53_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 56.6%, transparent 56.6%);
# }
# #T_19a53_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 48.8%, transparent 48.8%);
# }
# #T_19a53_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 75.5%, transparent 75.5%);
# }
# #T_19a53_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 29.6%, transparent 29.6%);
# }
# #T_19a53_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_19a53_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 19.6%, transparent 19.6%);
# }
# #T_19a53_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 43.5%, transparent 43.5%);
# }
# #T_19a53_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 15.7%, transparent 15.7%);
# }
# </style>
# <table id="T_19a53">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19a53_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_19a53_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_19a53_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_19a53_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SumAssuredBand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19a53_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_19a53_row0_col0" class="data row0 col0" >2,513,809</td>
#       <td id="T_19a53_row0_col1" class="data row0 col1" >10,088</td>
#       <td id="T_19a53_row0_col2" class="data row0 col2" >6.94%</td>
#       <td id="T_19a53_row0_col3" class="data row0 col3" >0.4013%</td>
#     </tr>
#     <tr>
#       <th id="T_19a53_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_19a53_row1_col0" class="data row1 col0" >6,930,909</td>
#       <td id="T_19a53_row1_col1" class="data row1 col1" >13,565</td>
#       <td id="T_19a53_row1_col2" class="data row1 col2" >19.12%</td>
#       <td id="T_19a53_row1_col3" class="data row1 col3" >0.1957%</td>
#     </tr>
#     <tr>
#       <th id="T_19a53_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_19a53_row2_col0" class="data row2 col0" >9,242,826</td>
#       <td id="T_19a53_row2_col1" class="data row2 col1" >10,975</td>
#       <td id="T_19a53_row2_col2" class="data row2 col2" >25.50%</td>
#       <td id="T_19a53_row2_col3" class="data row2 col3" >0.1187%</td>
#     </tr>
#     <tr>
#       <th id="T_19a53_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_19a53_row3_col0" class="data row3 col0" >12,238,301</td>
#       <td id="T_19a53_row3_col1" class="data row3 col1" >9,637</td>
#       <td id="T_19a53_row3_col2" class="data row3 col2" >33.77%</td>
#       <td id="T_19a53_row3_col3" class="data row3 col3" >0.0787%</td>
#     </tr>
#     <tr>
#       <th id="T_19a53_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_19a53_row4_col0" class="data row4 col0" >5,319,656</td>
#       <td id="T_19a53_row4_col1" class="data row4 col1" >3,356</td>
#       <td id="T_19a53_row4_col2" class="data row4 col2" >14.68%</td>
#       <td id="T_19a53_row4_col3" class="data row4 col3" >0.0631%</td>
#     </tr>
#   </tbody>
# </table>

# %%
###########################################################################
###########################################################################

num_feat = ["CommencementYear", "SumAssuredBand", "Age", "Duration"]

###########################################################################
###########################################################################

# Check correlations between numerical variables 
corr_mat = round(df_data[num_feat].corr(), 2)

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr_mat, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr_mat[mask] = np.nan

fig, ax = plt.subplots(figsize=(10, 6))
ax = sns.heatmap(
    corr_mat,
    annot=True,
    annot_kws={"size": label_fontsize},
    fmt=".0%",
    vmin=-1,
    vmax=1,
    cmap="coolwarm",
)

colorbar = ax.collections[0].colorbar 
colorbar.ax.tick_params(labelsize=label_fontsize) 
colorbar.ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))

ax.set_facecolor("white")
ax.set_yticklabels(df_data[num_feat].columns, fontsize=ticker_fontsize, rotation=0)
ax.set_xticklabels(df_data[num_feat].columns, fontsize=ticker_fontsize, rotation=90)
# Out:
# [Text(0.5, 0, 'CommencementYear'),
#  Text(1.5, 0, 'SumAssuredBand'),
#  Text(2.5, 0, 'Age'),
#  Text(3.5, 0, 'Duration')]

# %% [markdown]
# ### Map categorical levels to integer values

# %%
##########################################################################
##########################################################################

# Define a list of categorical variables
cat_feat = [
    "ProductCategory",
    "Gender",
    "SmokerStatus",
    "DistributionChannel",
    "JointLifeStatus",
    "CalendarYear",
]

cat_band_file = f"{dir_export}/CMI Categorical Bands (with CalendarYear).xlsx"

##########################################################################
##########################################################################

# Create categorical bandings for the first variable
v = cat_feat[0]
df_ = pd.DataFrame(df_data[v].unique(), columns=["Categorical_Level"])
df_.sort_values("Categorical_Level", inplace=True)
df_["Integer_Value"] = list(range(len(df_)))

df_data[v + "_cat_level"] = df_data[v].map(
    df_.set_index("Categorical_Level").to_dict()["Integer_Value"]
)

# Save down the categorical bandings
with pd.ExcelWriter(cat_band_file, engine="openpyxl", mode="w") as writer:
    df_.to_excel(writer, sheet_name=v, index=False)

for v in cat_feat[1:]:
    df_ = pd.DataFrame(df_data[v].unique(), columns=["Categorical_Level"])
    df_.sort_values("Categorical_Level", inplace=True)
    df_["Integer_Value"] = list(range(len(df_)))

    df_data[v + "_cat_level"] = df_data[v].map(
        df_.set_index("Categorical_Level").to_dict()["Integer_Value"]
    )

    with pd.ExcelWriter(
        cat_band_file,
        engine="openpyxl",
        mode="a",
    ) as writer:
        df_.to_excel(writer, sheet_name=v, index=False)

# %%
###################################################################
###################################################################

# Check the distribution of one categorical variable
v = "CalendarYear"

###################################################################
###################################################################

df_data_gb = df_data.groupby([v, v + "_cat_level"])[[weight, target]].sum()
df_data_gb[mix] = df_data_gb[weight] / df_data_gb[weight].sum()
df_data_gb[freq] = df_data_gb[target] / df_data_gb[weight]
df_data_gb.sort_values(freq, inplace=True)

df_data_gb.style.pipe(
    lambda x: make_pretty_pivot(x, format_dict, caption, bar_dict)
)
# Out:
# <style type="text/css">
# #T_1bbdd caption {
#   font-weight: bold;
#   font-size: 100%;
#   background-color: #000066;
#   color: white;
# }
# #T_1bbdd th {
#   border: 1px solid white;
# }
# #T_1bbdd td {
#   border: 1px solid #000066;
#   text-align: center;
# }
# #T_1bbdd tr {
#   border: 1px solid #000066;
# }
# #T_1bbdd .index_name {
#   border: 1px solid #000066;
# }
# #T_1bbdd th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_1bbdd_row0_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 89.1%, transparent 89.1%);
# }
# #T_1bbdd_row0_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 87.3%, transparent 87.3%);
# }
# #T_1bbdd_row1_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 92.1%, transparent 92.1%);
# }
# #T_1bbdd_row1_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 87.5%, transparent 87.5%);
# }
# #T_1bbdd_row2_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 95.1%, transparent 95.1%);
# }
# #T_1bbdd_row2_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 88.3%, transparent 88.3%);
# }
# #T_1bbdd_row3_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 97.5%, transparent 97.5%);
# }
# #T_1bbdd_row3_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 89.0%, transparent 89.0%);
# }
# #T_1bbdd_row4_col2 {
#   width: 5em;
#   background: linear-gradient(90deg, steelblue 100.0%, transparent 100.0%);
# }
# #T_1bbdd_row4_col3 {
#   width: 5em;
#   background: linear-gradient(90deg, darkcyan 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_1bbdd">
#   <caption>Claim Frequency</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bbdd_level0_col0" class="col_heading level0 col0" >LivesExposure</th>
#       <th id="T_1bbdd_level0_col1" class="col_heading level0 col1" >IncurredClaims</th>
#       <th id="T_1bbdd_level0_col2" class="col_heading level0 col2" >mix</th>
#       <th id="T_1bbdd_level0_col3" class="col_heading level0 col3" >actual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CalendarYear</th>
#       <th class="index_name level1" >CalendarYear_cat_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bbdd_level0_row0" class="row_heading level0 row0" >CY2016</th>
#       <th id="T_1bbdd_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_1bbdd_row0_col0" class="data row0 col0" >6,818,697</td>
#       <td id="T_1bbdd_row0_col1" class="data row0 col1" >8,638</td>
#       <td id="T_1bbdd_row0_col2" class="data row0 col2" >18.81%</td>
#       <td id="T_1bbdd_row0_col3" class="data row0 col3" >0.1267%</td>
#     </tr>
#     <tr>
#       <th id="T_1bbdd_level0_row1" class="row_heading level0 row1" >CY2017</th>
#       <th id="T_1bbdd_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_1bbdd_row1_col0" class="data row1 col0" >7,044,035</td>
#       <td id="T_1bbdd_row1_col1" class="data row1 col1" >8,938</td>
#       <td id="T_1bbdd_row1_col2" class="data row1 col2" >19.43%</td>
#       <td id="T_1bbdd_row1_col3" class="data row1 col3" >0.1269%</td>
#     </tr>
#     <tr>
#       <th id="T_1bbdd_level0_row2" class="row_heading level0 row2" >CY2018</th>
#       <th id="T_1bbdd_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_1bbdd_row2_col0" class="data row2 col0" >7,273,102</td>
#       <td id="T_1bbdd_row2_col1" class="data row2 col1" >9,319</td>
#       <td id="T_1bbdd_row2_col2" class="data row2 col2" >20.07%</td>
#       <td id="T_1bbdd_row2_col3" class="data row2 col3" >0.1281%</td>
#     </tr>
#     <tr>
#       <th id="T_1bbdd_level0_row3" class="row_heading level0 row3" >CY2019</th>
#       <th id="T_1bbdd_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_1bbdd_row3_col0" class="data row3 col0" >7,460,428</td>
#       <td id="T_1bbdd_row3_col1" class="data row3 col1" >9,629</td>
#       <td id="T_1bbdd_row3_col2" class="data row3 col2" >20.58%</td>
#       <td id="T_1bbdd_row3_col3" class="data row3 col3" >0.1291%</td>
#     </tr>
#     <tr>
#       <th id="T_1bbdd_level0_row4" class="row_heading level0 row4" >CY2020</th>
#       <th id="T_1bbdd_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_1bbdd_row4_col0" class="data row4 col0" >7,649,238</td>
#       <td id="T_1bbdd_row4_col1" class="data row4 col1" >11,097</td>
#       <td id="T_1bbdd_row4_col2" class="data row4 col2" >21.10%</td>
#       <td id="T_1bbdd_row4_col3" class="data row4 col3" >0.1451%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Export files

# %%
df_data.set_index(unique_id).to_parquet(
    f"{dir_export}/gam_modelling_data_{data_version}.parquet",
    engine="pyarrow",
    compression="gzip",
)
