# %% [markdown]
# # Interaction Detection with GBM
# ## Setup
# ### Import Python Packages

# %%
import os 
import xgboost as xgb
import pandas as pd 
import numpy as np 
import random 
import pyarrow.parquet as pq
import sys

# import shutil
import pickle
import warnings
from itertools import chain
import torch
from sklearn.metrics import mean_absolute_percentage_error
import graphviz
from scipy.stats import pearsonr

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

import optuna
from optuna.visualization import matplotlib as optunampl

# Internal packages 
sys.path.append("../")
sys.path.append("../../")
from src import utils

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 260)
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Set Variables

# %%
# Fontsize for visualisation
tick_fontsize = 14
label_fontsize = 18
title_fontsize = 22

# Define utility columns
exposure = "Policies_Exposed"
holdout = "holdout"
random_fold = "random_fold"
num_fold = 5

# Define actual and expected death count columns in the data
act_death = "Death_Count"
exp_death_mi = "ExpDth_VBT2015wMI_Cnt"
gam_rel_death = "ypred_death_count_rel"
data_version = "_ml_cy_split"
model_version = "_cy_split"

# Data
data_file = f"../export/Modelling_data (Filtered and Grouped by Selected Features){data_version}.parquet"
sf_pred_file = f"../export/Single Factor Model Predictions{model_version}.parquet"
xgb_pred_file = f"../export/XGB Model Predictions{model_version}.parquet"

# Define the modelling log that records key metrics in this notebook
modelling_log = f"../output/03_model_note_xgb_interaction_detection{model_version}.xlsx"

# Define the name of the residual GBM model
xgb_output = f"../output/residual_xgb{model_version}.json"

# %% [markdown]
# ## Create Modelling Data

# %%
# Import the modelling data
model_data = pd.read_parquet(data_file)
# Import the single factor GAM predictions
ypred_df = pd.read_parquet(sf_pred_file)
# Join the GAM predictions onto the modelling data
model_data = model_data.join(ypred_df[gam_rel_death])
model_data
# Out:
#            Observation_Year Sex Smoker_Status  Issue_Age  Duration  \
# unique_id
# 0                      2012   M            NS         34        17
# 1                      2012   M            NS         34        17
# 2                      2012   M            NS         34        17
# 3                      2012   M            NS         34        17
# 4                      2012   M            NS         34        17
# ...                     ...  ..           ...        ...       ...
# 612760                 2019   M             S         76         2
# 612761                 2019   M             S         76         2
# 612762                 2019   M             S         78         2
# 612763                 2019   M             S         80         4
# 612764                 2019   M             S         80         7
#
#                 Face_Amount_Band  Issue_Year  Attained_Age  Death_Count  \
# unique_id
# 0          05: 100,000 - 249,999        1996            50          0.0
# 1          06: 250,000 - 499,999        1995            50          0.0
# 2          06: 250,000 - 499,999        1996            50          2.0
# 3          07: 500,000 - 999,999        1995            50          0.0
# 4          07: 500,000 - 999,999        1996            50          0.0
# ...                          ...         ...           ...          ...
# 612760             01: 0 - 9,999        2018            77          0.0
# 612761       02: 10,000 - 24,999        2017            77          0.0
# 612762       02: 10,000 - 24,999        2017            79          0.0
# 612763       02: 10,000 - 24,999        2015            83          0.0
# 612764       02: 10,000 - 24,999        2012            86          0.0
#
#            Policies_Exposed  ExpDth_VBT2015wMI_Cnt  is_test  is_validation  \
# unique_id
# 0               1546.786003               2.355224     True          False
# 1                792.154739               1.203345     True          False
# 2               1031.760315               1.567217    False          False
# 3                327.323694               0.497118    False          False
# 4                458.157228               0.694401    False          False
# ...                     ...                    ...      ...            ...
# 612760             0.882192               0.018247    False          False
# 612761             0.213699               0.004420    False          False
# 612762             0.512329               0.012250    False          False
# 612763             0.082192               0.004593    False          False
# 612764             0.380822               0.032084    False          False
#
#            Sex_cat_level  Smoker_Status_cat_level  Face_Amount_Band_ordinal  \
# unique_id
# 0                      1                        0                         5
# 1                      1                        0                         6
# 2                      1                        0                         6
# 3                      1                        0                         7
# 4                      1                        0                         7
# ...                  ...                      ...                       ...
# 612760                 1                        1                         1
# 612761                 1                        1                         2
# 612762                 1                        1                         2
# 612763                 1                        1                         2
# 612764                 1                        1                         2
#
#            holdout  random_fold  act_death_rate  exp_death_rate_mi  \
# unique_id
# 0                0            2        0.000000           0.001523
# 1                0            3        0.000000           0.001519
# 2                0            1        0.001938           0.001519
# 3                0            5        0.000000           0.001519
# 4                0            5        0.000000           0.001516
# ...            ...          ...             ...                ...
# 612760           1            6        0.000000           0.020683
# 612761           1            6        0.000000           0.020683
# 612762           1            6        0.000000           0.023910
# 612763           1            6        0.000000           0.055880
# 612764           1            6        0.000000           0.084249
#
#            ypred_death_count_rel
# unique_id
# 0                       2.596612
# 1                       1.070574
# 2                       1.394393
# 3                       0.392685
# 4                       0.549643
# ...                          ...
# 612760                  0.045977
# 612761                  0.013948
# 612762                  0.044361
# 612763                  0.015380
# 612764                  0.104354
#
# [612765 rows x 21 columns]

# %%
# Check the null rates 
model_data.isnull().sum()
# Out:
# Observation_Year            0
# Sex                         0
# Smoker_Status               0
# Issue_Age                   0
# Duration                    0
# Face_Amount_Band            0
# Issue_Year                  0
# Attained_Age                0
# Death_Count                 0
# Policies_Exposed            0
# ExpDth_VBT2015wMI_Cnt       0
# is_test                     0
# is_validation               0
# Sex_cat_level               0
# Smoker_Status_cat_level     0
# Face_Amount_Band_ordinal    0
# holdout                     0
# random_fold                 0
# act_death_rate              0
# exp_death_rate_mi           0
# ypred_death_count_rel       0
# dtype: int64

# %%
###########################################################################
###########################################################################

# Define the list of numerical features
num_feat = [
    "Observation_Year", 
    "Duration", 
    "Attained_Age", 
    "Face_Amount_Band_ordinal",
    # "Issue_Age",
    # "Issue_Year",
]

# Define the list of categorical features
cat_feat = ["Sex_cat_level", "Smoker_Status_cat_level"]

###########################################################################
###########################################################################

# Define the full feature list
all_feat = num_feat + cat_feat
print(all_feat)
# Out:
# ['Observation_Year', 'Duration', 'Attained_Age', 'Face_Amount_Band_ordinal', 'Sex_cat_level', 'Smoker_Status_cat_level']

# %% [markdown]
# ### Encode categorical variables

# %%
cat_feat_encoded = []
cat_feat_encoded_all = []
cat_feat_raw = [x.replace("_cat_level", "") for x in cat_feat]

for var in cat_feat_raw: 
    if len(model_data[var].unique()) > 2: 
        cat_feat_encoded.append(var + "_cat_level")
        for level in model_data[var].unique(): 
            model_data[f"{var}.{str(level)}"] = np.where(
                model_data[var] == level, 1, 0
            )
            cat_feat_encoded_all.append(f"{var}.{str(level)}")

print(cat_feat_encoded)
print(cat_feat_encoded_all)
# Out:
# []
# []

# %%
# Define the final factor list used in GBM
final_feature_gbm = (
    num_feat + [x for x in cat_feat if x not in cat_feat_encoded] + cat_feat_encoded_all
)
print(final_feature_gbm)
# Out:
# ['Observation_Year', 'Duration', 'Attained_Age', 'Face_Amount_Band_ordinal', 'Sex_cat_level', 'Smoker_Status_cat_level']

# %% [markdown]
# ### Define required dataframes

# %%
# Define the training and holdout dataframes
X_train = model_data.loc[model_data[holdout] == 0, final_feature_gbm]
y_train = model_data.loc[model_data[holdout] == 0, act_death]
w_train = model_data.loc[model_data[holdout] == 0, exposure]
start_train = model_data.loc[model_data[holdout] == 0, gam_rel_death]

X_test = model_data.loc[model_data[holdout] == 1, final_feature_gbm]
y_test = model_data.loc[model_data[holdout] == 1, act_death]
w_test = model_data.loc[model_data[holdout] == 1, exposure]
start_test = model_data.loc[model_data[holdout] == 1, gam_rel_death]

# Define the cross-validation folds required for hyperparameter tuning
random_fold_values = model_data.loc[model_data[holdout] == 0, random_fold].values

# Define a list of tuples, each first element contains indices for the training fold and each second element contains indices for the holdout
folds = []
df_ = pd.DataFrame(
    zip(range(len(random_fold_values)), random_fold_values),
    columns=["row_index", random_fold],
)

for i in range(max(random_fold_values)):
    index_train = df_[df_[random_fold] != i + 1]["row_index"].to_list()
    index_valid = df_[df_[random_fold] == i + 1]["row_index"].to_list()
    folds.append((index_train, index_valid))

valid_folds = [k[1] for k in folds]
check = np.sort(np.array(list(chain(*valid_folds)))) == np.arange(len(X_train))

assert check.sum() == len(
    X_train
), "Not all the rows in the training data are included in the data folds."

# %%
# Define the data matrices for XGB training 
dtrain = xgb.DMatrix(
    data=X_train,
    label=y_train, 
    base_margin=np.log(start_train),
)
dtest = xgb.DMatrix(
    data=X_test, 
    label=y_test, 
    base_margin=np.log(start_test)
)

# %% [markdown]
# ## XGB Training
# ### Hyperparameter Tuning  using Optuna

# %%
###########################################################################
###########################################################################

has_cuda = torch.cuda.is_available()
eta = 0.1
tree_method = "hist"
device = "cuda" if has_cuda else "cpu"
xgb_objective = "count:poisson"
metric = "poisson-nloglik"
seed = 1997
num_boost_round = 10000
early_stopping_round = 30
n_trials = 25
# monotone_constraints = {
#     "Issue_Year": -1,
#     "Duration": 1,
#     "Face_Amount_Band_ordinal": -1,
# }

###########################################################################
###########################################################################

print(device)
# Out:
# cpu

# %%
# Define an objective function for Optuna
def objective(trial):
    params = {
        "eta": eta,
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 1e3, log=True),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.5, 1),
        "subsample": trial.suggest_float("subsample", 0.5, 1),
        "gamma": trial.suggest_float("gamma", 1e-6, 1.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 2, 2),
        "tree_method": tree_method,
        
        "device": device,
        "objective": xgb_objective,
        "eval_metric": metric,
        "seed": seed,
        # "monotone_constraints": monotone_constraints,
    }

    xgb_cv = xgb.cv(
        dtrain=dtrain,
        params=params,
        seed=seed,
        num_boost_round=num_boost_round,
        metrics=metric,
        early_stopping_rounds=early_stopping_round,
        folds=folds,
    )
    return xgb_cv[f"test-{metric}-mean"].min()

# %%
study = optuna.create_study(direction="minimize")
# Out:
# [I 2026-04-19 19:28:24,923] A new study created in memory with name: no-name-fe5fd93d-cc8c-4f40-8709-9a6541ec3f90

# %%
study.optimize(objective, n_trials=n_trials)
# Out:
# [I 2026-04-19 19:33:03,440] Trial 0 finished with value: 0.5269762851603617 and parameters: {'min_child_weight': 461, 'colsample_bytree': 0.8378501799135007, 'colsample_bylevel': 0.9864372893268893, 'subsample': 0.9286027810050023, 'gamma': 0.6235730551613378, 'max_depth': 2}. Best is trial 0 with value: 0.5269762851603617.
# [I 2026-04-19 19:36:14,608] Trial 1 finished with value: 0.5254974762683713 and parameters: {'min_child_weight': 542, 'colsample_bytree': 0.9885966706977596, 'colsample_bylevel': 0.5881578924439967, 'subsample': 0.8037652783349278, 'gamma': 0.0008411727234474308, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:39:36,103] Trial 2 finished with value: 0.5255619925631094 and parameters: {'min_child_weight': 426, 'colsample_bytree': 0.578276560254688, 'colsample_bylevel': 0.9931254947096637, 'subsample': 0.7437973214683952, 'gamma': 3.713008074789315e-05, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:42:37,651] Trial 3 finished with value: 0.5255906387453917 and parameters: {'min_child_weight': 215, 'colsample_bytree': 0.5477296182802102, 'colsample_bylevel': 0.8821608380845836, 'subsample': 0.6196124296705405, 'gamma': 0.16630491783332615, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:45:17,204] Trial 4 finished with value: 0.5255291393491335 and parameters: {'min_child_weight': 64, 'colsample_bytree': 0.7227573567435357, 'colsample_bylevel': 0.5587146365644377, 'subsample': 0.8899303439504733, 'gamma': 2.581423476074297e-05, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:49:45,354] Trial 5 finished with value: 0.5257564030659541 and parameters: {'min_child_weight': 1, 'colsample_bytree': 0.649979419574301, 'colsample_bylevel': 0.6586945956560972, 'subsample': 0.8652081933779338, 'gamma': 4.433431259500985e-06, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:52:32,604] Trial 6 finished with value: 0.525513819994228 and parameters: {'min_child_weight': 1, 'colsample_bytree': 0.9165732934602862, 'colsample_bylevel': 0.5514520531755707, 'subsample': 0.9276801516211709, 'gamma': 5.3714257992230906e-05, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:54:38,310] Trial 7 finished with value: 0.5255439731319106 and parameters: {'min_child_weight': 5, 'colsample_bytree': 0.8376960246303371, 'colsample_bylevel': 0.8857669132038791, 'subsample': 0.9368263477995724, 'gamma': 1.9570685428286497e-06, 'max_depth': 2}. Best is trial 1 with value: 0.5254974762683713.
# [I 2026-04-19 19:57:29,312] Trial 8 finished with value: 0.5254934254585156 and parameters: {'min_child_weight': 32, 'colsample_bytree': 0.7609674746172205, 'colsample_bylevel': 0.8026126700385231, 'subsample': 0.7114965907019801, 'gamma': 0.00018321409993188046, 'max_depth': 2}. Best is trial 8 with value: 0.5254934254585156.
# [I 2026-04-19 20:01:12,043] Trial 9 finished with value: 0.5255204492420502 and parameters: {'min_child_weight': 25, 'colsample_bytree': 0.5235314973043941, 'colsample_bylevel': 0.8842454607312883, 'subsample': 0.7354215803168771, 'gamma': 0.14731475328640584, 'max_depth': 2}. Best is trial 8 with value: 0.5254934254585156.
# [I 2026-04-19 20:04:05,717] Trial 10 finished with value: 0.525575378613805 and parameters: {'min_child_weight': 7, 'colsample_bytree': 0.7588464711933172, 'colsample_bylevel': 0.7461472803762279, 'subsample': 0.5172780164396757, 'gamma': 0.004685059092673519, 'max_depth': 2}. Best is trial 8 with value: 0.5254934254585156.

# %%
# Print best trial
best_trial_number = study.best_trial.number
best_trial_value = study.best_trial.value
print(f"Best trial: {best_trial_number} with value {best_trial_value}\n{'*'*80}")

# Print out the best parameters
best_hyperparams = study.best_params
print(best_hyperparams)
# Out:
# Best trial: 42 with value 0.5254372850974982
# ********************************************************************************
# {'min_child_weight': 459, 'colsample_bytree': 0.8585672175882275, 'colsample_bylevel': 0.8356573758171147, 'subsample': 0.8851970562326499, 'gamma': 1.056700295533336e-06, 'max_depth': 2}

# %%
# Save the tuning progress
with pd.ExcelWriter(
    f"{modelling_log}", engine="openpyxl"
) as writer:
    study.trials_dataframe().sort_values("value").to_excel(
        writer, sheet_name="XGB_Tune", index=False
    )

# %%
plt.figure()
plt.rcParams["figure.figsize"] = [10, 5]
optunampl.plot_optimization_history(study)

plt.figure()
plt.rcParams["figure.figsize"] = [10, 5]
optunampl.plot_param_importances(study)

plt.figure()
plt.rcParams["figure.figsize"] = [10, 5]
optunampl.plot_edf(study)
# Out:
# <Axes: title={'center': 'Empirical Distribution Function Plot'}, xlabel='Objective Value', ylabel='Cumulative Probability'>

# %%
param_importance = optuna.importance.get_param_importances(study)

plt.figure()
plt.rcParams["figure.figsize"] = [20, 8]
optunampl.plot_parallel_coordinate(study, params=list(param_importance)[:3])

plt.figure()
plt.rcParams["figure.figsize"] = [20, 8]
optunampl.plot_contour(study, params=list(param_importance)[:3])

plt.figure()
plt.rcParams["figure.figsize"] = [20, 8]
optunampl.plot_slice(study, params=list(param_importance)[:3])
# Out:
# array([<Axes: xlabel='gamma', ylabel='Objective Value'>,
#        <Axes: xlabel='min_child_weight'>, <Axes: xlabel='subsample'>],
#       dtype=object)

# %% [markdown]
# ### Tune # trees

# %%
study_df = pd.read_excel(f"{modelling_log}", "XGB_Tune")
best_params = study_df.sort_values("value").filter(regex="params_").iloc[0].to_dict()
best_params = {k.replace("params_", ""): v for k, v in best_params.items()}
best_params["max_depth"] = int(best_params["max_depth"])
print(best_params)
# Out:
# {'colsample_bylevel': 0.8356573758171147, 'colsample_bytree': 0.8585672175882275, 'gamma': 1.056700295533336e-06, 'max_depth': 2, 'min_child_weight': 459.0, 'subsample': 0.8851970562326499}

# %%
###########################################################################
###########################################################################

all_params = {
    "eta": eta,
    "tree_method": tree_method,
    "objective": xgb_objective,
    "eval_metric": metric,
    "device": device,
    "seed": seed,
    # "monotone_constraints": monotone_constraints,
    **best_params,
}

verbose = 100

###########################################################################
###########################################################################

xgb_cv = xgb.cv(
    dtrain=dtrain,
    params=all_params,
    seed=seed,
    num_boost_round=num_boost_round,
    metrics=metric,
    early_stopping_rounds=early_stopping_round,
    folds=folds,
    verbose_eval=verbose,
)
# Out:
# [0]	train-poisson-nloglik:0.53016+0.00037	test-poisson-nloglik:0.53016+0.00147
# [100]	train-poisson-nloglik:0.52932+0.00035	test-poisson-nloglik:0.52942+0.00145
# [200]	train-poisson-nloglik:0.52876+0.00035	test-poisson-nloglik:0.52891+0.00145
# [300]	train-poisson-nloglik:0.52836+0.00036	test-poisson-nloglik:0.52853+0.00143
# [400]	train-poisson-nloglik:0.52800+0.00035	test-poisson-nloglik:0.52821+0.00142
# [500]	train-poisson-nloglik:0.52773+0.00035	test-poisson-nloglik:0.52796+0.00141
# [600]	train-poisson-nloglik:0.52748+0.00034	test-poisson-nloglik:0.52774+0.00141
# [700]	train-poisson-nloglik:0.52724+0.00033	test-poisson-nloglik:0.52752+0.00142
# [800]	train-poisson-nloglik:0.52705+0.00035	test-poisson-nloglik:0.52736+0.00139
# [900]	train-poisson-nloglik:0.52685+0.00036	test-poisson-nloglik:0.52717+0.00138
# [1000]	train-poisson-nloglik:0.52667+0.00035	test-poisson-nloglik:0.52701+0.00138
# [1100]	train-poisson-nloglik:0.52651+0.00035	test-poisson-nloglik:0.52688+0.00139
# [1200]	train-poisson-nloglik:0.52638+0.00034	test-poisson-nloglik:0.52676+0.00139
# [1300]	train-poisson-nloglik:0.52623+0.00033	test-poisson-nloglik:0.52663+0.00141
# [1400]	train-poisson-nloglik:0.52610+0.00033	test-poisson-nloglik:0.52652+0.00140
# [1500]	train-poisson-nloglik:0.52600+0.00033	test-poisson-nloglik:0.52643+0.00141
# [1600]	train-poisson-nloglik:0.52590+0.00034	test-poisson-nloglik:0.52634+0.00140
# [1700]	train-poisson-nloglik:0.52580+0.00034	test-poisson-nloglik:0.52626+0.00140
# [1800]	train-poisson-nloglik:0.52571+0.00034	test-poisson-nloglik:0.52619+0.00140
# [1900]	train-poisson-nloglik:0.52564+0.00034	test-poisson-nloglik:0.52613+0.00141
# [2000]	train-poisson-nloglik:0.52557+0.00034	test-poisson-nloglik:0.52608+0.00141
# [2100]	train-poisson-nloglik:0.52549+0.00034	test-poisson-nloglik:0.52602+0.00140
# [2200]	train-poisson-nloglik:0.52543+0.00034	test-poisson-nloglik:0.52597+0.00140
# [2300]	train-poisson-nloglik:0.52537+0.00034	test-poisson-nloglik:0.52593+0.00140
# [2400]	train-poisson-nloglik:0.52532+0.00034	test-poisson-nloglik:0.52589+0.00141
# [2500]	train-poisson-nloglik:0.52527+0.00034	test-poisson-nloglik:0.52585+0.00140
# [2600]	train-poisson-nloglik:0.52522+0.00034	test-poisson-nloglik:0.52582+0.00141
# [2700]	train-poisson-nloglik:0.52517+0.00034	test-poisson-nloglik:0.52579+0.00141
# [2800]	train-poisson-nloglik:0.52514+0.00035	test-poisson-nloglik:0.52576+0.00141
# [2900]	train-poisson-nloglik:0.52510+0.00035	test-poisson-nloglik:0.52573+0.00140
# [3000]	train-poisson-nloglik:0.52506+0.00035	test-poisson-nloglik:0.52571+0.00141
# [3100]	train-poisson-nloglik:0.52502+0.00035	test-poisson-nloglik:0.52569+0.00141
# [3200]	train-poisson-nloglik:0.52499+0.00035	test-poisson-nloglik:0.52567+0.00141
# [3300]	train-poisson-nloglik:0.52496+0.00035	test-poisson-nloglik:0.52565+0.00141
# [3400]	train-poisson-nloglik:0.52493+0.00035	test-poisson-nloglik:0.52563+0.00141
# [3500]	train-poisson-nloglik:0.52490+0.00035	test-poisson-nloglik:0.52561+0.00141
# [3600]	train-poisson-nloglik:0.52487+0.00035	test-poisson-nloglik:0.52559+0.00141
# [3700]	train-poisson-nloglik:0.52485+0.00035	test-poisson-nloglik:0.52558+0.00141
# [3800]	train-poisson-nloglik:0.52483+0.00035	test-poisson-nloglik:0.52557+0.00141
# [3900]	train-poisson-nloglik:0.52480+0.00035	test-poisson-nloglik:0.52556+0.00141
# [4000]	train-poisson-nloglik:0.52478+0.00035	test-poisson-nloglik:0.52555+0.00141
# [4100]	train-poisson-nloglik:0.52476+0.00035	test-poisson-nloglik:0.52554+0.00141
# [4200]	train-poisson-nloglik:0.52474+0.00035	test-poisson-nloglik:0.52553+0.00141
# [4300]	train-poisson-nloglik:0.52472+0.00035	test-poisson-nloglik:0.52552+0.00141
# [4400]	train-poisson-nloglik:0.52470+0.00035	test-poisson-nloglik:0.52551+0.00141
# [4500]	train-poisson-nloglik:0.52468+0.00035	test-poisson-nloglik:0.52551+0.00141
# [4600]	train-poisson-nloglik:0.52466+0.00035	test-poisson-nloglik:0.52550+0.00141
# [4700]	train-poisson-nloglik:0.52465+0.00035	test-poisson-nloglik:0.52550+0.00142
# [4800]	train-poisson-nloglik:0.52463+0.00035	test-poisson-nloglik:0.52549+0.00141
# [4900]	train-poisson-nloglik:0.52462+0.00035	test-poisson-nloglik:0.52548+0.00142
# [5000]	train-poisson-nloglik:0.52460+0.00035	test-poisson-nloglik:0.52548+0.00141
# [5100]	train-poisson-nloglik:0.52459+0.00035	test-poisson-nloglik:0.52547+0.00141
# [5200]	train-poisson-nloglik:0.52457+0.00035	test-poisson-nloglik:0.52547+0.00141
# [5300]	train-poisson-nloglik:0.52456+0.00035	test-poisson-nloglik:0.52546+0.00141
# [5400]	train-poisson-nloglik:0.52455+0.00035	test-poisson-nloglik:0.52546+0.00141
# [5500]	train-poisson-nloglik:0.52453+0.00035	test-poisson-nloglik:0.52545+0.00141
# [5600]	train-poisson-nloglik:0.52452+0.00035	test-poisson-nloglik:0.52545+0.00141
# [5700]	train-poisson-nloglik:0.52451+0.00035	test-poisson-nloglik:0.52544+0.00141
# [5800]	train-poisson-nloglik:0.52450+0.00035	test-poisson-nloglik:0.52544+0.00141
# [5866]	train-poisson-nloglik:0.52449+0.00035	test-poisson-nloglik:0.52544+0.00141

# %%
xgb_cv.rename(
    columns={f"train-{metric}-mean": "Train", f"test-{metric}-mean": "Out-of-Fold"}, 
    inplace=True,
)

plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 1.25
plt.rcParams["figure.figsize"] = [10, 6]

fig, ax = plt.subplots(1)

sns.lineplot(
    data=xgb_cv[["Train", "Out-of-Fold"]], 
    ax=ax, 
)

ax.grid(False)
ax.set_facecolor("white")

ax.legend(facecolor="white", edgecolor="black")
ax.set_title(f"Cross-Validated Deviance Loss by Number of Trees")
# Out:
# Text(0.5, 1.0, 'Cross-Validated Deviance Loss by Number of Trees')

# %% [markdown]
# ## Train the XGB model

# %%
best_iteration = len(xgb_cv)
bst = xgb.train(all_params, dtrain, best_iteration)

bst.save_model(xgb_output)

# %% [markdown]
# ### Holdout Model Performance

# %%
bst = xgb.Booster()
bst.load_model(xgb_output)

# %%
####################################################################
####################################################################

xgb_rate = "ypred_xgb_death_rate"
xgb_count = "ypred_xgb_death_count"

####################################################################
####################################################################

ypred_test = bst.predict(dtest)
ypred_test_df = pd.DataFrame(ypred_test, columns=[xgb_count], index=X_test.index)
ypred_test_df = ypred_test_df.join(start_test).join(y_test).join(model_data[exposure])
ypred_test_df[xgb_rate] = ypred_test_df[xgb_count] / ypred_test_df[exposure]
ypred_test_df["ypred_death_rate_rel"] = (
    ypred_test_df[gam_rel_death] / ypred_test_df[exposure]
)
ypred_test_df
# Out:
#            ypred_xgb_death_count  ypred_death_count_rel  Death_Count  \
# unique_id
# 450356                  0.037039               0.055709          0.0
# 450357                  0.107703               0.162028          0.0
# 450358                  0.099131               0.149132          0.0
# 450359                  0.025596               0.045788          0.0
# 450360                  0.039084               0.023970          0.0
# ...                          ...                    ...          ...
# 612760                  0.098757               0.045977          0.0
# 612761                  0.015047               0.013948          0.0
# 612762                  0.047984               0.044361          0.0
# 612763                  0.010080               0.015380          0.0
# 612764                  0.049810               0.104354          0.0
#
#            Policies_Exposed  ypred_xgb_death_rate  ypred_death_rate_rel
# unique_id
# 450356            91.000000              0.000407              0.000612
# 450357           422.884931              0.000255              0.000383
# 450358           389.227398              0.000255              0.000383
# 450359           148.441095              0.000172              0.000308
# 450360            32.493151              0.001203              0.000738
# ...                     ...                   ...                   ...
# 612760             0.882192              0.111945              0.052117
# 612761             0.213699              0.070413              0.065270
# 612762             0.512329              0.093658              0.086587
# 612763             0.082192              0.122646              0.187118
# 612764             0.380822              0.130795              0.274023
#
# [162409 rows x 6 columns]

# %%
gam_dev = utils.total_poisson_dev(
    y=ypred_test_df[act_death], 
    y_pred=ypred_test_df[gam_rel_death],
)
xgb_dev = utils.total_poisson_dev(
    y=ypred_test_df[act_death], 
    y_pred=ypred_test_df[xgb_count],
)

print(f"{'GAM (Single-Factor)':<20}: {gam_dev:,.0f}")
print(f"{'XGBoost':<20}: {xgb_dev:,.0f}")
# Out:
# GAM (Single-Factor) : 84,637
# XGBoost             : 83,525

# %%
corr, _ = pearsonr(
    ypred_test_df["ypred_xgb_death_rate"], ypred_test_df["ypred_death_rate_rel"]
)
print(f"Correlation between GAM Rel and SOA Expected Death Rate: {corr:.2%}")
# Out:
# Correlation between GAM Rel and SOA Expected Death Rate: 92.82%

# %%
################################################################
################################################################

# Define the list of new to current model prediction column names
predict = [xgb_count, gam_rel_death]

################################################################
################################################################

d = utils.DoubleLift(
    ypred_test_df, predict, "Death_Count", exposure, [0.01, 0.95], approx_num_band=25
)

mape_xgb = mean_absolute_percentage_error(
    d.double_lift_table["Death_Count"],
    d.double_lift_table[predict[0]],
    sample_weight=d.double_lift_table[exposure],
)
mape_gam = mean_absolute_percentage_error(
    d.double_lift_table["Death_Count"],
    d.double_lift_table[predict[1]],
    sample_weight=d.double_lift_table[exposure],
)
print(f"{'MAPE - XGB':<30}: {mape_xgb:.2%}")
print(f"{'MAPE - GAM Rel':<30}: {mape_gam:.2%}")

d.double_lift_table
# Out:
# MAPE - XGB                    : 2.60%
# MAPE - GAM Rel                : 8.14%
#        ratio_band  Death_Count  ypred_xgb_death_count  ypred_death_count_rel  \
# band
# 1          <= 0.6     0.000513               0.000550               0.000996
# 2     (0.6, 0.65]     0.001384               0.001526               0.002434
# 3     (0.65, 0.7]     0.000948               0.000921               0.001359
# 4     (0.7, 0.75]     0.001415               0.001433               0.001968
# 5     (0.75, 0.8]     0.001584               0.001641               0.002120
# 6     (0.8, 0.85]     0.001148               0.001078               0.001303
# 7     (0.85, 0.9]     0.001693               0.001660               0.001884
# 8     (0.9, 0.95]     0.002229               0.002146               0.002311
# 9     (0.95, 1.0]     0.001800               0.001780               0.001829
# 10    (1.0, 1.05]     0.001449               0.001472               0.001441
# 11    (1.05, 1.1]     0.001432               0.001436               0.001338
# 12    (1.1, 1.15]     0.001776               0.001837               0.001637
# 13    (1.15, 1.2]     0.001941               0.002014               0.001717
# 14    (1.2, 1.25]     0.001976               0.002093               0.001711
# 15    (1.25, 1.3]     0.002052               0.002085               0.001638
# 16    (1.3, 1.35]     0.002019               0.002115               0.001600
# 17    (1.35, 1.4]     0.002437               0.002449               0.001784
# 18    (1.4, 1.45]     0.001987               0.002188               0.001538
# 19    (1.45, 1.5]     0.001914               0.001943               0.001318
# 20    (1.5, 1.55]     0.001854               0.001929               0.001267
# 21    (1.55, 1.6]     0.001116               0.001391               0.000884
# 22    (1.6, 1.65]     0.001525               0.001544               0.000950
# 23    (1.65, 1.7]     0.001510               0.001761               0.001051
# 24    (1.7, 1.75]     0.001361               0.001684               0.000979
# 25    (1.75, 1.8]     0.001380               0.001794               0.001012
# 26          > 1.8     0.001772               0.002019               0.000957
#
#       Policies_Exposed
# band
# 1         2.999604e+05
# 2         1.683643e+05
# 3         3.206166e+05
# 4         5.786046e+05
# 5         6.400202e+05
# 6         1.205170e+06
# 7         3.060903e+06
# 8         6.436937e+06
# 9         1.064598e+07
# 10        7.029330e+06
# 11        4.417955e+06
# 12        2.126918e+06
# 13        1.329235e+06
# 14        1.071504e+06
# 15        6.593086e+05
# 16        4.135500e+05
# 17        2.621880e+05
# 18        2.324748e+05
# 19        1.917335e+05
# 20        1.494107e+05
# 21        2.025025e+05
# 22        1.160309e+05
# 23        7.812435e+04
# 24        7.717277e+04
# 25        7.463692e+04
# 26        2.883746e+05

# %%
###########################################################################
###########################################################################

param_dict = {
    "title": "Double Lift - XGB to GAM Rel Death Count", 
    "leftylabel": "Claim Incidence Rate", 
    "rightylabel": "Life Years Exposure Mix",
    "target_legend": "Actual Observed", 
    "new_model_legend": "XGB",
    "baseline_legend": "GAM Rel",
    "palette": ["tab:blue", "#DAA520", "#A52A2A"]
}

###########################################################################
###########################################################################

plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"] = 1.25

fig, ax = plt.subplots(figsize=(12, 6))

d.plot_double_lift(ax=ax, **param_dict)

# %% [markdown]
# ## Model Explanation
# ### Feature Importance

# %%
###########################################################################
###########################################################################

importance_type = "total_gain"

###########################################################################
###########################################################################

xgb_imp_df = pd.DataFrame( 
    bst.get_score(importance_type=importance_type).items(), 
    columns=["Feature", "Importance"]
)

# Clean up the feature name
xgb_imp_df["Feature_Agg"] = (
    xgb_imp_df["Feature"].str.split(".").str[0]
)
xgb_imp_df["Feature_Agg"] = (
    xgb_imp_df["Feature_Agg"]
    .str.replace("_cat_level", "")
    .str.replace("_level", "")
)

# Aggregate the importance dataframe 
xgb_imp_df_agg = (
    xgb_imp_df.groupby(
        ["Feature_Agg"], as_index=False
    )[["Importance"]].sum()
)
xgb_imp_df_agg.sort_values("Importance", inplace=True, ascending=False)

xgb_imp_df_agg["Importance_Norm"] = (
    xgb_imp_df_agg["Importance"] / xgb_imp_df_agg["Importance"].sum()
)
xgb_imp_df_agg
# Out:
#                 Feature_Agg    Importance  Importance_Norm
# 2  Face_Amount_Band_ordinal  19935.396484         0.395836
# 0              Attained_Age  11136.215820         0.221120
# 5             Smoker_Status   7739.291016         0.153671
# 1                  Duration   5647.558105         0.112138
# 4                       Sex   3014.437744         0.059855
# 3          Observation_Year   2889.818848         0.057380

# %%
plt.rcParams["figure.figsize"] = (12, 8)
plt.rcParams["axes.edgecolor"] = "black"

fig, ax = plt.subplots(1)

sns.barplot(
    data=xgb_imp_df_agg, 
    y="Feature_Agg", 
    x="Importance_Norm", 
    color="tab:blue", 
    ax=ax,
)

# Do some formating in the x and y axes to make them easier to read
xticker = ax.get_xticks() 
xlabel = [f'{x:,.0%}' for x in xticker]
ax.set_xticklabels(xlabel, fontsize=tick_fontsize)

ylabel = xgb_imp_df_agg["Feature_Agg"] 
ax.set_yticklabels(ylabel, fontsize=tick_fontsize)

ax.set_facecolor("white")

ax.set_xlabel("")
ax.set_ylabel("")

ax.set_title("XGB Factor Importance", fontsize=title_fontsize)
# Out:
# Text(0.5, 1.0, 'XGB Factor Importance')

# %% [markdown]
# ### Actual vs Expected Analysis on Holdout

# %%
##################################################################
##################################################################

key_features = [x.replace("_ordinal", "") for x in xgb_imp_df["Feature_Agg"]]

##################################################################
##################################################################

# Initialise an empty dict for holding the grouped by dataframes
risk_agg_dict = {}

for v in key_features:
    # Perform risk aggregations by individual features
    df_gb = utils.risk_agg(
        ypred_test_df.join(model_data[key_features]),
        v,
        exposure,
        act_death,
        gam_rel_death_count=gam_rel_death,
        xgb_death_count=xgb_count,
    )
    # We're doing Actual vs Expected analysis
    df_gb["gam_rel_death_rate"] = df_gb["actual_death_rate"] / df_gb["gam_rel_death_rate"]
    df_gb["xgb_death_rate"] = df_gb["actual_death_rate"] / df_gb["xgb_death_rate"]

    risk_agg_dict[v] = df_gb

# %%
##############################################################################################
##############################################################################################

y1_label = "Claim Incidence Rate"
y2_label = "Life Years Exposure"

##############################################################################################
##############################################################################################

for var in key_features:

    fig, ax = plt.subplots(1, figsize=(12, 7))
    # Plot incidence rates
    sns.lineplot(
        data=risk_agg_dict[var].loc[:, ["xgb_death_rate", "gam_rel_death_rate"]],
        ax=ax,
        markers=True,
        dashes=False,
        palette=["#DAA520", "#A52A2A"],
    )
    ax.axhline(y=1, color="black", linestyle="--", label="A=E")

    # Set title and x and y axes labels and fontsize
    ax.set_ylabel(y1_label, fontsize=label_fontsize)
    ax.set_xlabel("")
    ax.set_title(var + " (Actual / Expected)", fontsize=title_fontsize)
    ax.tick_params(axis="both", which="major", labelsize=tick_fontsize)

    # Fix the xticker labels if there are decimal places in xtickers when variable should be integers
    if not isinstance(risk_agg_dict[var].index[0], str):
        index_has_decimals = any(val % 1 != 0 for val in risk_agg_dict[var].index)
        ticks_have_decimals = any(tick % 1 != 0 for tick in ax.get_xticks())

        if not index_has_decimals and ticks_have_decimals:
            ax.set_xticks(risk_agg_dict[var].index)
            ax.set_xticklabels(risk_agg_dict[var].index)

    # Format x-axis tickers
    ax.tick_params(
        axis="x",
        rotation=(
            90
            if isinstance(risk_agg_dict[var].index[0], str)
            and len(risk_agg_dict[var].index[0]) > 4
            else 0
        ),
    )

    # Create secondary y-axis for exposures
    ax2 = ax.twinx()
    ax2.bar(
        risk_agg_dict[var].index,
        risk_agg_dict[var][exposure],
        color="lightgray",
        alpha=0.5,
        ec="k",
        label=y2_label,
    )

    # Format secondary y-axis ticker
    ax2.yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f"{x/1000:,.0f}k"))
    ax2.tick_params(axis="y", which="major", labelsize=tick_fontsize)

    # Combine legends
    lines, labels = ax.get_legend_handles_labels()
    bars, bar_labels = ax2.get_legend_handles_labels()
    ax.legend(
        lines + bars,
        labels + bar_labels,
        loc="best",
        fontsize=tick_fontsize,
        facecolor="white",
    )

    # Set secondary y-axis label
    ax2.set_ylabel(y2_label, fontsize=label_fontsize)

    # Define order of layering
    ax.set_zorder(2)
    ax.patch.set_alpha(0)
    ax2.set_zorder(1)

# %% [markdown]
# ## Derive interaction importance

# %%
# Plot one tree to visualise it
fig, ax = plt.subplots(figsize=(12, 12))
xgb.plot_tree(bst, num_trees=1999, ax=ax)
# Out:
# <Axes: >

# %%
# Get the node details
node_df = bst.trees_to_dataframe()

# Clean up the feature name
node_df["Feature"] = (
    node_df["Feature"].str.split(".").str[0]
)
node_df["Feature"] = (
    node_df["Feature"]
    .str.replace("_cat_level", "")
    .str.replace("_level", "")
)
node_df
# Out:
#        Tree  Node      ID                   Feature   Split     Yes      No  \
# 0         0     0     0-0          Observation_Year  2017.0     0-1     0-2
# 1         0     1     0-1             Smoker_Status     1.0     0-3     0-4
# 2         0     2     0-2             Smoker_Status     1.0     0-5     0-6
# 3         0     3     0-3                      Leaf     NaN     NaN     NaN
# 4         0     4     0-4                      Leaf     NaN     NaN     NaN
# ...     ...   ...     ...                       ...     ...     ...     ...
# 40164  5836     2  5836-2  Face_Amount_Band_ordinal    10.0  5836-5  5836-6
# 40165  5836     3  5836-3                      Leaf     NaN     NaN     NaN
# 40166  5836     4  5836-4                      Leaf     NaN     NaN     NaN
# 40167  5836     5  5836-5                      Leaf     NaN     NaN     NaN
# 40168  5836     6  5836-6                      Leaf     NaN     NaN     NaN
#
#       Missing      Gain          Cover  Category
# 0         0-2  0.182418  357929.406000       NaN
# 1         0-4  1.120746  293532.875000       NaN
# 2         0-6  5.587486   64396.527300       NaN
# 3         NaN  0.000039  252554.594000       NaN
# 4         NaN -0.000243   40978.296900       NaN
# ...       ...       ...            ...       ...
# 40164  5836-6  0.000717    2453.677000       NaN
# 40165     NaN  0.000049  166553.453000       NaN
# 40166     NaN -0.000009  189305.812000       NaN
# 40167     NaN -0.000659    1605.321170       NaN
# 40168     NaN -0.000723     848.355957       NaN
#
# [40169 rows x 11 columns]

# %%
# Get the parent node for every tree 
node_df_0 = node_df[node_df.Node == 0]

# Join the features used to split in the next level (Yes)
node_df_0_Y = node_df_0.merge(
    node_df[["ID", "Feature", "Gain"]], 
    left_on="Yes", 
    right_on="ID", 
    suffixes=("", "1"),
)
node_df_0_Y = node_df_0_Y[
    node_df_0_Y["Feature1"] != "Leaf"
]
node_df_0_Y = node_df_0_Y[
    node_df_0_Y["Feature"] != node_df_0_Y["Feature1"]
]
node_df_0_Y["Feature_List"] = (
    node_df_0_Y.apply(lambda x: np.sort([x.Feature, x.Feature1]), axis=1)
)
node_df_0_Y = node_df_0_Y[["Feature_List", "Gain1"]]
print(node_df_0_Y.head())

# Join the features used to split in the next level (No)
node_df_0_N = node_df_0.merge(
    node_df[["ID", "Feature", "Gain"]], 
    left_on="No", 
    right_on="ID", 
    suffixes=("", "1"),
)
node_df_0_N = node_df_0_N[
    node_df_0_N["Feature1"] != "Leaf"
]
node_df_0_N = node_df_0_N[
    node_df_0_N["Feature"] != node_df_0_N["Feature1"]
]
node_df_0_N["Feature_List"] = (
    node_df_0_N.apply(lambda x: np.sort([x.Feature, x.Feature1]), axis=1)
)
node_df_0_N = node_df_0_N[["Feature_List", "Gain1"]]
print(node_df_0_N.head())
# Out:
#                                Feature_List       Gain1
# 0         [Observation_Year, Smoker_Status]    1.120746
# 1  [Attained_Age, Face_Amount_Band_ordinal]   59.291805
# 2  [Attained_Age, Face_Amount_Band_ordinal]   49.509674
# 3      [Duration, Face_Amount_Band_ordinal]   56.573845
# 4      [Duration, Face_Amount_Band_ordinal]  136.464722
#                                Feature_List       Gain1
# 0         [Observation_Year, Smoker_Status]    5.587486
# 1  [Attained_Age, Face_Amount_Band_ordinal]  120.177933
# 2  [Attained_Age, Face_Amount_Band_ordinal]   51.944862
# 3      [Duration, Face_Amount_Band_ordinal]   94.358131
# 4      [Duration, Face_Amount_Band_ordinal]   66.065681

# %%
# Aggregate Gains to two-way interactions 
two_way_gain_df = pd.concat([node_df_0_Y, node_df_0_N], axis=0)
two_way_gain_df["Feature_List"] = two_way_gain_df["Feature_List"].apply(
    lambda x: " x ".join(x)
)
two_way_gain_df = two_way_gain_df.groupby(
    ["Feature_List"], as_index=False
)[["Gain1"]].sum()
two_way_gain_df = two_way_gain_df.sort_values("Gain1", ascending=False)
two_way_gain_df["Gain_Norm"] = (
    two_way_gain_df["Gain1"] / two_way_gain_df["Gain1"].sum()
)

# %%
plt.rcParams["figure.figsize"] = (15, 10)
plt.rcParams["axes.edgecolor"] = "black"

fig, ax = plt.subplots(1)

sns.barplot(
    data=two_way_gain_df, 
    y="Feature_List", 
    x="Gain_Norm", 
    color="tab:blue", 
    ax=ax,
)

# Do some formating in the x and y axes to make them easier to read
xticker = ax.get_xticks() 
xlabel = [f'{x:,.0%}' for x in xticker]
ax.set_xticklabels(xlabel, fontsize=tick_fontsize)

ylabel = two_way_gain_df["Feature_List"] 
ax.set_yticklabels(ylabel, fontsize=tick_fontsize)

ax.set_facecolor("white")

ax.set_xlabel("")
ax.set_ylabel("")

ax.set_title("Interaction Importance", fontsize=title_fontsize)
# Out:
# Text(0.5, 1.0, 'Interaction Importance')

# %%
with pd.ExcelWriter(
    f"{modelling_log}", engine="openpyxl", mode="a", if_sheet_exists="replace"
) as writer:
    two_way_gain_df.to_excel(
        writer, sheet_name="Inter_Imp_GBM", index=False
    )

# %% [markdown]
# ## Save down XGB-enhanced GAM predictions for comparison

# %%
# Define a dataframe that contains predictions, target and weight
ypred_train = bst.predict(dtrain)

ypred_train_df = pd.DataFrame(
    ypred_train, columns=["ypred_xgb_death_count"], index=X_train.index
).join(w_train)

ypred_train_df["ypred_xgb_death_rate"] = (
    ypred_train_df["ypred_xgb_death_count"] / ypred_train_df[exposure]
)
ypred_train_df
# Out:
#            ypred_xgb_death_count  Policies_Exposed  ypred_xgb_death_rate
# unique_id
# 0                       2.800696       1546.786003              0.001811
# 1                       1.176503        792.154739              0.001485
# 2                       1.532361       1031.760315              0.001485
# 3                       0.451367        327.323694              0.001379
# 4                       0.631781        458.157228              0.001379
# ...                          ...               ...                   ...
# 450351                  0.000819          0.041096              0.019940
# 450352                  0.003544          1.945205              0.001822
# 450353                  0.001553          0.728767              0.002131
# 450354                  0.001615          0.301370              0.005359
# 450355                  0.005067          0.501370              0.010107
#
# [450356 rows x 3 columns]

# %%
ypred_df = pd.concat(
    [
        ypred_train_df[["ypred_xgb_death_count", "ypred_xgb_death_rate"]],
        ypred_test_df[["ypred_xgb_death_count", "ypred_xgb_death_rate"]],
    ],
    axis=0,
)
ypred_df = ypred_df.sort_index()
ypred_df
# Out:
#            ypred_xgb_death_count  ypred_xgb_death_rate
# unique_id
# 0                       2.800696              0.001811
# 1                       1.176503              0.001485
# 2                       1.532361              0.001485
# 3                       0.451367              0.001379
# 4                       0.631781              0.001379
# ...                          ...                   ...
# 612760                  0.098757              0.111945
# 612761                  0.015047              0.070413
# 612762                  0.047984              0.093658
# 612763                  0.010080              0.122646
# 612764                  0.049810              0.130795
#
# [612765 rows x 2 columns]

# %%
ypred_df.to_parquet(xgb_pred_file)
